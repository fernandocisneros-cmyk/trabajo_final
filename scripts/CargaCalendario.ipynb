# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

# %%
directorio=Path.cwd()
print("Directorio actual:", directorio)
# Out:
# Directorio actual: c:\Users\ferna\OneDrive\Certified Python Data Scientist\github\trabajo_final\scripts

# %%
os.chdir('c:\\Users\\ferna\\OneDrive\\Certified Python Data Scientist\\github\\trabajo_final\\data\\external')
directorio=Path.cwd()
print("Directorio actual:", directorio)

file_path = Path("calendar.csv")

if file_path.exists():
    print("El archivo existe.")
else:
    print("El archivo no existe.")


print(f"ubicacion archivo {file_path}")
# Out:
# Directorio actual: c:\Users\ferna\OneDrive\Certified Python Data Scientist\github\trabajo_final\data\external
# El archivo existe.
# ubicacion archivo calendar.csv

# %%
df=pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  str
#  2   available   1393570 non-null  str
#  3   price       934542 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 42.5 MB

# %%
df
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 2            241032  2016-01-06         f     NaN
# 3            241032  2016-01-07         f     NaN
# 4            241032  2016-01-08         f     NaN
# ...             ...         ...       ...     ...
# 1393565    10208623  2016-12-29         f     NaN
# 1393566    10208623  2016-12-30         f     NaN
# 1393567    10208623  2016-12-31         f     NaN
# 1393568    10208623  2017-01-01         f     NaN
# 1393569    10208623  2017-01-02         f     NaN
#
# [1393570 rows x 4 columns]
