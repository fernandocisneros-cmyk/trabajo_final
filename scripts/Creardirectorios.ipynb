# %% [markdown]
# Generacion Token: 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

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

# %% [markdown]
# Ingresamos al directorio

# %%
os.chdir('C:\\Users\\ferna\\OneDrive\\Certified Python Data Scientist\\github\\trabajo_final')
directorio=Path.cwd()
print("Directorio actual:", directorio)
# Out:
# Directorio actual: C:\Users\ferna\OneDrive\Certified Python Data Scientist\github\trabajo_final

# %% [markdown]
# Creamos los directorios para el repsitorio

# %%
os.makedirs('data/raw', exist_ok=True)
os.makedirs('data/processed', exist_ok=True)
os.makedirs('data/external', exist_ok=True)
os.makedirs('notebooks/exploracion', exist_ok=True)
os.makedirs('notebooks/limpieza', exist_ok=True)
os.makedirs('notebooks/modelado', exist_ok=True)
os.makedirs('scripts', exist_ok=True)
os.makedirs('reportes/figuras', exist_ok=True)
